# %% [markdown]
# # TorchVison Notes
#
# - Based on https://www.youtube.com/watch?v=V_xro1bcAuA&t=53062s

# %% [markdown]
# ### Loading the Data, FashionMNIST

# %%
#Getting a dataset from pytorch
from torchvision import datasets
import torch

train_data = datasets.FashionMNIST(
    root = 'data', #Where do we want to download the data?
    train = True, #Do we want the training dataset?
    download = True, #Do we want to download the data?
    transform = ToTensor(), #how do we want to transform the images, need to transform to tensor
    target_transform = None #we dont want to transform the labels, target we are trying to predict
)

test_data = datasets.FashionMNIST(
    root = 'data',
    train = False, #only change from above since we dont want the train set in this test set.
    download = True,
    transform = ToTensor(),
    target_transform = None
)
# Out:
#   File "<ipython-input-1-6b9195051958>", line 5
#     train = True #Do we want the training dataset?
#             ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ### Building a model to recognize patterns in the data
