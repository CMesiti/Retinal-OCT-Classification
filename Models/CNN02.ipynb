# %%
#Second Attempt at Fine-Tuning a CNN for OCT image Classification.

#This attempt we will fine tune the EfficientNetV2_b0 from hugging face
#This attempt we will use the UCSD Dataset
#This attempt we will apply image pre-processing to enhance the contrast of the ROI
#Edit the training loop and fix any errors

# %% [markdown]
# # Fine-Tuning Attempt #2
# https://www.frontiersin.org/journals/computer-science/articles/10.3389/fcomp.2023.1252295/full
# - Model, https://huggingface.co/timm/tf_efficientnetv2_b0.in1k
# - Dataset, https://data.mendeley.com/datasets/rscbjbr9sj.
# - Optimizer, Adam
# - Loss Function, CrossEntropy
# - Pre-Processing, Using OpenCV
#
# 1. Load Data
# 2. Pre-Process (CLAHE Contrast Limited Adaptive Histogram Equalization)
# 3. DataLoader
# 4. Visualize Data
# 3. Load Model
# 4. Training Loop
# 5. Evaluation
# 6. Visualize Predictions

# %%
#imports

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import cv2 as cv
import random
from glob import glob
from torchvision import datasets
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from torch import nn
from torch import optim
import os
import timm
from timm import create_model
from PIL import Image

# %%
# !pip install timm
# Out:
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (1.0.11)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from timm) (2.5.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm) (0.20.0+cu121)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm) (6.0.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from timm) (0.24.7)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm) (0.4.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (4.66.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->timm) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->timm) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->timm) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->timm) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm) (2024.8.30)

# %% [markdown]
# ## Loading Data

# %%
#Loading the data from the UCSD Large Dataset.
# !kaggle datasets download -d mmazizi/ucsd-3-class-labeled-retinal-oct-images
# !unzip ucsd-3-class-labeled-retinal-oct-images.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9193451-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9193451-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9193451-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9193451-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9193451-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9193451-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9193451-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9194489-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9194489-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9194489-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9194489-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9194489-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9194489-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9194489-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9194489-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9194489-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9194489-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9196735-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9196735-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9196735-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9196735-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9196735-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9196735-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9196735-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200488-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200488-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200488-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200488-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200488-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200488-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200488-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200488-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200488-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200488-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200488-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-12.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-13.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-14.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-15.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-16.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-17.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-18.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-19.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-20.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-21.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-22.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-23.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-24.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-25.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-26.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-27.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-28.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9200900-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-12.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-13.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-14.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-15.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-16.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-17.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-18.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-19.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-20.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-21.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-22.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-23.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-24.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-25.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-26.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-27.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-28.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-29.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-30.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-31.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202950-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202975-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202975-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202975-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202975-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202975-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202975-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202975-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202975-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202975-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9202975-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9203192-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9203192-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9203192-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9203192-12.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9203192-13.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9203192-14.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9203192-15.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9203192-16.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9203192-17.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9203192-18.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9203192-19.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9203192-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9203192-20.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9203192-21.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9203192-22.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9203192-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9203192-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9203192-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9203192-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9203192-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9203192-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9203192-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9204206-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9204206-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9204206-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9204206-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9204206-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9204206-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9204206-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9204206-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9204206-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9204206-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9205792-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9205792-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9205792-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9205792-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9205792-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9205792-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9205792-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9205792-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9205792-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9205792-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206244-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206244-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206244-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206244-12.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206244-13.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206244-14.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206244-15.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206244-16.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206244-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206244-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206244-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206244-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206244-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206244-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206244-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206244-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-12.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-13.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-14.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-15.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-16.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-17.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-18.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-19.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-20.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-21.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-22.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-23.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-24.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-25.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-26.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-27.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-28.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-29.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-30.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-31.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9206635-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-12.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-13.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-14.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-15.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-16.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-17.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-18.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-19.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-20.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-21.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-22.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-23.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-24.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9211360-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9215613-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9215613-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9215613-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9215613-12.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9215613-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9215613-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9215613-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9215613-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9215613-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9215613-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9215613-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9215613-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9216703-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9216703-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9216703-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9216703-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9216703-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9216703-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9216703-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9216703-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9216703-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9216703-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9217961-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9217961-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9217961-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9217961-12.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9217961-13.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9217961-14.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9217961-15.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9217961-16.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9217961-17.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9217961-18.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9217961-19.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9217961-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9217961-20.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9217961-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9217961-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9217961-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9217961-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9217961-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9217961-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9217961-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9218595-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9218595-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9218595-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9218595-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9218595-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9218595-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9219561-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9219561-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9219561-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9219561-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9219561-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9219561-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9219561-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9219561-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9219561-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9219561-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9219673-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9219673-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9219673-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9219673-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9219673-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9219673-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9219673-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9219673-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9219673-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9219673-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9222390-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9222390-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9222390-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9222390-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9222390-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9222390-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9222390-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9222390-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9222390-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9222709-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9222709-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9222709-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9222709-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9222709-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9222709-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9222709-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9222709-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9222709-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9222709-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9222709-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226215-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226215-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226215-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226215-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226215-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226215-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226215-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226215-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226215-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226215-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-12.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-13.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-14.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-15.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-16.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-17.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-18.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-19.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-20.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-21.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-22.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-23.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-24.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-25.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-26.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-27.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-28.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-29.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-30.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-31.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-32.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-33.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-34.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-35.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-36.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-37.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-38.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-39.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-40.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-41.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-42.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-43.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-44.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226319-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-12.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-13.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-14.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-15.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-16.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-17.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-18.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-19.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-20.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-21.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-22.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-23.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-24.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-25.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-26.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-27.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-28.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-29.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-30.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-31.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-32.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-33.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-34.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-35.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-36.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-37.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-38.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-39.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-40.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9226664-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9229999-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9229999-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9229999-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9229999-12.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9229999-13.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9229999-14.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9229999-15.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9229999-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9229999-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9229999-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9229999-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9229999-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9229999-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9229999-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9229999-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9232014-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9232014-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9232014-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9232014-12.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9232014-13.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9232014-14.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9232014-15.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9232014-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9232014-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9232014-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9232014-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9232014-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9232014-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9232014-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9232014-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9236278-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9236278-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9236278-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9236278-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9236278-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9236278-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9236278-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9236278-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9236278-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9236278-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9237838-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9237838-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9237838-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9237838-12.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9237838-13.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9237838-14.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9237838-15.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9237838-16.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9237838-17.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9237838-18.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9237838-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9237838-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9237838-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9237838-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9237838-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9237838-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9237838-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9237838-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240050-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240050-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240050-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240050-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240050-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240050-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240050-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240050-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240050-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240050-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-12.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-13.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-14.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-15.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-16.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-17.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-18.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-19.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-20.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-21.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-22.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-23.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-24.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-25.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-26.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-27.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-28.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-29.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-30.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9240933-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9241179-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9241179-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9241179-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9241179-12.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9241179-13.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9241179-14.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9241179-15.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9241179-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9241179-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9241179-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9241179-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9241179-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9241179-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9241179-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9241179-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9244847-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9244847-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9244847-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9244847-12.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9244847-13.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9244847-14.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9244847-15.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9244847-16.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9244847-17.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9244847-18.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9244847-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9244847-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9244847-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9244847-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9244847-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9244847-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9244847-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9244847-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9245828-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9245828-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9245828-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9245828-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9245828-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9245828-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9245828-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9245828-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9245828-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9245828-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9246841-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9246841-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9246841-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9246841-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9246841-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9246841-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9246841-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9246841-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9246841-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9246841-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9249454-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9249454-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9249454-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9249454-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9249454-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9249454-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9249454-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9249454-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9249454-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9251-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9251-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9251-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9251-12.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9251-13.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9251-14.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9251-15.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9251-16.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9251-17.jpeg
# ...
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9961073-42.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9961073-43.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9961073-44.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9961073-45.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9961073-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9961073-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9961073-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9961073-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9961073-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9961809-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9961809-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9961809-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9961809-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9961809-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9961809-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-997131-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-997131-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-997131-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-997131-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-997131-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-997131-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-997131-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-997131-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-997131-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-997131-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9971430-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9971430-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9971430-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9971430-12.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9971430-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9971430-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9971430-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9971430-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9971430-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9971430-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9971430-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9971430-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9972304-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9972304-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9972304-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9972304-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9972304-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9972304-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9972304-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9972304-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9972304-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9972304-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9974984-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9974984-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9974984-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9974984-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9974984-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9974984-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9974984-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9974984-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9974984-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9974984-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984129-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984129-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984129-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984129-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984129-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984129-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984129-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984129-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984129-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984129-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984841-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984841-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984841-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984841-12.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984841-13.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984841-14.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984841-15.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984841-16.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984841-17.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984841-18.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984841-19.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984841-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984841-20.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984841-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984841-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984841-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984841-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984841-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984841-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9984841-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9988725-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9988725-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9988725-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9988725-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9988725-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9988725-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9988725-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-12.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-13.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-14.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-15.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-16.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-17.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-18.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-19.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-20.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-21.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-22.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-23.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-24.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-25.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-26.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-27.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-28.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-29.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-30.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9990284-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992270-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992270-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992270-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992270-12.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992270-13.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992270-14.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992270-15.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992270-16.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992270-17.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992270-18.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992270-19.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992270-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992270-20.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992270-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992270-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992270-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992270-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992270-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992270-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992270-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992694-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992694-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992694-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992694-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992694-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992694-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992694-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992694-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992694-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9992694-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9993521-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9993521-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9993521-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9993521-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9993521-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9993521-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9993521-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9993521-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9995842-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9995842-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9995842-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9995842-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9995842-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9995842-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9995842-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9995842-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9995842-9.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9996356-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9996356-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9996356-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9996356-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9996356-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9996356-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9997680-1.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9997680-10.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9997680-11.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9997680-2.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9997680-3.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9997680-4.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9997680-5.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9997680-6.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9997680-7.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9997680-8.jpeg
#   inflating: OCTUCSD-3class/OCTUCSD-3class/OCT/train/NORMAL/NORMAL-9997680-9.jpeg
#   inflating: ucsd_test.csv
#   inflating: ucsd_train.csv
#   inflating: ucsd_val.csv

# %% [markdown]
# ### Visualize Dataset

# %%
#we want a dataframe, reading in datasets with pandas reading the csv
#cvs label classes, 0:Drusen, 1:CNV, 2:Normal
#since ml works better with numbers we label each of the images with 0,1,2
csv_path = "/content/ucsd_train.csv"
df = pd.read_csv(csv_path)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                                file-name  class-id
# 0         16794       16794        OCT/train/CNV/CNV-1781140-39.jpeg         1
# 1         60242       60242  OCT/train/NORMAL/NORMAL-4446447-11.jpeg         2
# 2         74083       74083   OCT/train/NORMAL/NORMAL-4489896-8.jpeg         2
# 3         62436       62436  OCT/train/NORMAL/NORMAL-1193128-13.jpeg         2
# 4         88057       88057  OCT/train/NORMAL/NORMAL-7398942-30.jpeg         2

# %%
dataset_path = '/content/OCTUCSD-3class/OCTUCSD-3class/OCT/train'

# Initialize an empty list to store image information
image_data = []

# Loop through each folder in the dataset directory
for label_folder in os.listdir(dataset_path):
    label_path = os.path.join(dataset_path, label_folder)

    # Check if the current item is a directory (to avoid files in the dataset root)
    if os.path.isdir(label_path):
        # Loop through all images in the current label folder
        for image_file in os.listdir(label_path):
            # Get the full path of the image
            image_path = os.path.join(label_path, image_file)
            # Append the image path and label to the image_data list
            image_data.append([image_path, label_folder])

# Create a DataFrame from the list
df = pd.DataFrame(image_data, columns=['image_path', 'label'])

# Show the first few rows of the DataFrame to verify
print(df.head())
# Out:
#                                           image_path   label
# 0  /content/OCTUCSD-3class/OCTUCSD-3class/OCT/tra...  NORMAL
# 1  /content/OCTUCSD-3class/OCTUCSD-3class/OCT/tra...  NORMAL
# 2  /content/OCTUCSD-3class/OCTUCSD-3class/OCT/tra...  NORMAL
# 3  /content/OCTUCSD-3class/OCTUCSD-3class/OCT/tra...  NORMAL
# 4  /content/OCTUCSD-3class/OCTUCSD-3class/OCT/tra...  NORMAL

# %%
# Group by the 'label' column and count the number of images for each label
label_counts = df['label'].value_counts().reset_index()
# Rename the columns for better clarity
label_counts.columns = ['Label', 'Number of Images']
# Display the table
print(label_counts)
# Out:
#     Label  Number of Images
# 0  NORMAL             51140
# 1     CNV             37205
# 2  DRUSEN              8616

# %% [markdown]
# > Pytorch datasets and dataloaders, classes in pytorch that help us load and process data for ML problems, need efficient algorithms to load and process data. data loader takes a dataset loaded in and creates batch sizes, shuffles etc. Data is loaded into the dataset class through methods or attributes, this dataset class is then fed into the dataloader, this loads and accesses the data. The dataset class needs to know the length of the dataset.

# %%
#View Pre-Processing Techniques


image = cv.imread("/content/OCTUCSD-3class/OCTUCSD-3class/OCT/train/DRUSEN/DRUSEN-1001666-1.jpeg", cv.IMREAD_GRAYSCALE)  # Read grayscale
image = cv.resize(image, (224, 224))          # Resize
# Optionally apply CLAHE
clahe = cv.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
image_eq = clahe.apply(image)
image_blur = cv.GaussianBlur(image_eq, (3,3), 0)
kernel = cv.getStructuringElement(cv.MORPH_RECT, (5, 5))
image_closed = cv.morphologyEx(image, cv.MORPH_CLOSE, kernel)

#plot image processing techniques, 1,3 figure
fig, ax = plt.subplots( 1,4,figsize = (10,10)) #create visual layout for images, 2x2 grid
fig.tight_layout()          #layout images neatly

ax[0].imshow(image_eq, cmap='gray')
ax[0].set_title('CLAHE')

ax[1].imshow(image_blur, cmap='gray')
ax[1].set_title('Blur')

ax[2].imshow(image_closed, cmap='gray')
ax[2].set_title('Closed')

ax[3].imshow(image, cmap='gray')
ax[3].set_title('Original')
# Out:
# Text(0.5, 1.0, 'Original')

# %% [markdown]
# ### Read/Transform Dataset

# %%
#we want to use ~8000 of each image for our training, since we want to avoid bias in our model
#training the model on all 51000 normal images would cause bias towards normal.

#loading the training set, split this set into 80, 20 train, validation sets
#note x are features and y is the outcome
#x=image, y=label


#Read and process images, CLAHE and Gaussian Blur processsing using openCV
def read_process_images(path, image_size = (224,224) ):
  image = cv.imread(path, cv.IMREAD_GRAYSCALE)  # Read grayscale
  image = cv.resize(image, image_size)          # Resize
  # Optionally apply CLAHE, and Gaussian Blur
  clahe = cv.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
  image = clahe.apply(image)
  image = cv.GaussianBlur(image, (5,5), 0)
  #normalize intensity range. 0-1
  image = image / 255.0
  return image

#sample the image sets 8600 of each class to avoid bias
def sample_images(file_path, sample_size):
  img_path = os.path.join(file_path, "*.jpeg")
  images = glob(img_path)
  sample_set = random.sample(images, sample_size)
  #list comprehension, get processing images for each image in sample set, return a list of these processing imgs
  return [read_process_images(img_path) for img_path in sample_set]

# %%
train_path = "/content/OCTUCSD-3class/OCTUCSD-3class/OCT/train"
test_path = "/content/OCTUCSD-3class/OCTUCSD-3class/OCT/test"
image_size = (224,224)
train_size = 8000



norm_imgs = sample_images(os.path.join(train_path, "NORMAL"), train_size)
cnv_imgs = sample_images(os.path.join(train_path, "CNV"), train_size)
drusen_imgs = sample_images(os.path.join(train_path, "DRUSEN"), train_size)

#create image and label sets for dataloader
image_data = norm_imgs + cnv_imgs + drusen_imgs
labels = [0] * len(norm_imgs) + [1] * len(cnv_imgs) + [2] * len(drusen_imgs)

# %%
plt.imshow(drusen_imgs[1])

# %%
from torch.utils.data import Dataset, DataLoader, random_split
# Define the custom Dataset class
class OCTDataset(Dataset):
    def __init__(self, folder_paths, sample_size, image_size=(224, 224), transform=None):
        self.image_paths = []

        # Sample images from each class
        for path in folder_paths:
            images = glob(os.path.join(path, "*.jpeg"))
            sampled_images = random.sample(images, sample_size)
            self.image_paths.extend(sampled_images)

        self.image_size = image_size
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]

        # Read, resize, and pre-process image
        # Load and resize image with OpenCV
        img = cv.imread(img_path)
        img = cv.cvtColor(img, cv.COLOR_BGR2RGB)  # Convert BGR to RGB
        img = cv.resize(img, self.image_size)  # Resize to desired size (224, 224)

        # Convert image to tensor
        img = torch.from_numpy(img).float().permute(2, 0, 1) / 255.0  # Normalize to [0,1]

        if self.transform:
            img = self.transform(img)  # Apply additional transforms
        label = self.get_label_from_path(img_path)

        return img, label

    def get_label_from_path(self, path):
        if "NORMAL" in path:
            return 0
        elif "CNV" in path:
            return 1
        elif "DRUSEN" in path:
            return 2

# Define the dataset paths and initialize the Dataset and DataLoader
train_path = "/content/OCTUCSD-3class/OCTUCSD-3class/OCT/train"
folder_paths = [
    os.path.join(train_path, "NORMAL"),
    os.path.join(train_path, "CNV"),
    os.path.join(train_path, "DRUSEN")
]


sample_size = 4000  # Specify the number of images to sample from each class
# Create the dataset and data loader
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=3),  # Make grayscale images 3-channel
    transforms.Resize((224, 224)),                # Resize to 224x224
    transforms.ToTensor(),                        # Convert to tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize
])
full_dataset = OCTDataset(folder_paths, sample_size)
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size

train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=2)

# %%
train_features, train_labels = next(iter(train_loader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")

# Visualize one of the images in the batch
img = train_features[0].squeeze().permute(1, 2, 0).numpy()  # Convert from (C, H, W) to (H, W, C)
plt.imshow(img, cmap="gray")
plt.show()
print(f"Label: {train_labels[0]}")
print(f"Tyoe: {type(img)}")
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Feature batch shape: torch.Size([32, 3, 224, 224])
# Labels batch shape: torch.Size([32])
# Label: 1
# Tyoe: <class 'numpy.ndarray'>

# %% [markdown]
# ## Training Loop

# %%
from tqdm import tqdm

# Training loop function
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=10, device="cuda"):
    model.to(device)

    for epoch in range(num_epochs):
        print(f"Epoch {epoch + 1}/{num_epochs}")
        print("-" * 10)

        # Training phase
        model.train()  # Set model to training mode
        running_loss = 0.0
        correct_predictions = 0

        for inputs, labels in tqdm(train_loader):
            inputs, labels = inputs.to(device), labels.to(device)

            # Zero the parameter gradients
            optimizer.zero_grad()

            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Backward pass and optimize
            loss.backward()
            optimizer.step()

            # Statistics
            running_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            correct_predictions += torch.sum(preds == labels)

        epoch_loss = running_loss / len(train_loader.dataset)
        epoch_accuracy = correct_predictions.double() / len(train_loader.dataset)

        print(f"Train Loss: {epoch_loss:.4f} Acc: {epoch_accuracy:.4f}")

        # Validation phase
        model.eval()  # Set model to evaluate mode
        val_loss = 0.0
        correct_val_predictions = 0

        with torch.no_grad():  # Disable gradient computation for validation
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)

                # Forward pass
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                # Statistics
                val_loss += loss.item() * inputs.size(0)
                _, preds = torch.max(outputs, 1)
                correct_val_predictions += torch.sum(preds == labels)

        val_loss /= len(val_loader.dataset)
        val_accuracy = correct_val_predictions.double() / len(val_loader.dataset)

        print(f"Validation Loss: {val_loss:.4f} Acc: {val_accuracy:.4f}")

    print("Training complete")
    return model

# %%
# Load the EfficientNetV2-B0 model with pre-trained weights
model = timm.create_model("tf_efficientnetv2_b0", pretrained=True)

# Modify the final layer to match the number of classes (3 in this case)
num_classes = 3
model.classifier = nn.Linear(model.classifier.in_features, num_classes)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/28.8M [00:00<?, ?B/s]

# %%
from torch.optim import Adam

# Set up the optimizer and loss function
optimizer = Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# %%
# Assume train_loader and val_loader are defined as before
device = "cuda" if torch.cuda.is_available() else "cpu"
num_epochs = 5

# Train the model
trained_model = train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=num_epochs, device=device)
# Out:
# Epoch 1/5
# ----------
# 100%|██████████| 300/300 [32:29<00:00,  6.50s/it]
# Train Loss: 0.2461 Acc: 0.9134
# Validation Loss: 0.1631 Acc: 0.9442
# Epoch 2/5
# ----------
# 100%|██████████| 300/300 [32:54<00:00,  6.58s/it]
# Train Loss: 0.1332 Acc: 0.9559
# Validation Loss: 0.1515 Acc: 0.9529
# Epoch 3/5
# ----------
# 100%|██████████| 300/300 [32:31<00:00,  6.50s/it]
# Train Loss: 0.0919 Acc: 0.9680
# Validation Loss: 0.1708 Acc: 0.9467
# Epoch 4/5
# ----------
# 100%|██████████| 300/300 [32:46<00:00,  6.56s/it]
# Train Loss: 0.0661 Acc: 0.9783
# Validation Loss: 0.2038 Acc: 0.9317
# Epoch 5/5
# ----------
# 100%|██████████| 300/300 [32:39<00:00,  6.53s/it]
# Train Loss: 0.0783 Acc: 0.9720
# Validation Loss: 0.2206 Acc: 0.9396
# Training complete

# %%
import matplotlib.pyplot as plt
import torch

def visualize_predictions(model, dataloader, class_names, device):
    model.eval()  # Set the model to evaluation mode
    images, labels = next(iter(dataloader))  # Get a batch of images and labels
    images, labels = images.to(device), labels.to(device)

    with torch.no_grad():
        outputs = model(images)
        _, preds = torch.max(outputs, 1)

    # Plot the images with predictions
    fig = plt.figure(figsize=(12, 8))
    for idx in range(min(8, len(images))):  # Display up to 8 images
        ax = fig.add_subplot(2, 4, idx + 1, xticks=[], yticks=[])
        img = images[idx].cpu().numpy().transpose((1, 2, 0))  # Convert tensor to NumPy
        plt.imshow(img)
        ax.set_title(f"True: {class_names[labels[idx]]}\nPred: {class_names[preds[idx]]}")
    plt.show()

# %%
  #test_dataloader
# Define the custom Dataset class
class OCTDataset(Dataset):
    def __init__(self, folder_paths, sample_size, image_size=(224, 224), transform=None):
        self.image_paths = []

        # Sample images from each class
        for path in folder_paths:
            images = glob(os.path.join(path, "*.jpeg"))
            sampled_images = random.sample(images, sample_size)
            self.image_paths.extend(sampled_images)

        self.image_size = image_size
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        # Read, resize, and pre-process image
        # Load and resize image with OpenCV
        img = cv.imread(img_path)
        img = cv.cvtColor(img, cv.COLOR_BGR2RGB)  # Convert BGR to RGB
        img = cv.resize(img, self.image_size)  # Resize to desired size (224, 224)

        # Convert image to tensor
        img = torch.from_numpy(img).float().permute(2, 0, 1) / 255.0  # Normalize to [0,1]
        if self.transform:
            img = self.transform(img)  # Apply additional transforms
        label = self.get_label_from_path(img_path)

        return img, label

    def get_label_from_path(self, path):
        if "NORMAL" in path:
            return 0
        elif "CNV" in path:
            return 1
        elif "DRUSEN" in path:
            return 2

# Define the dataset paths and initialize the Dataset and DataLoader
test_path = "/content/OCTUCSD-3class/OCTUCSD-3class/OCT/test"
folder_paths = [
    os.path.join(test_path, "NORMAL"),
    os.path.join(test_path, "CNV"),
    os.path.join(test_path, "DRUSEN")
]

# Create the dataset and data loader
transform = transforms.Compose([
    transforms.Resize((224, 224)),                # Resize to 224x224
    transforms.ToTensor(),                        # Convert to tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize
])

sample_size = 100

test_dataset = OCTDataset(folder_paths, sample_size)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2)

# %%
#Get a variety of predictions from our model,
#test batch of 2cnv 2normal and 2drusen





#I need to get the test dataloader and a class names
class_names = ["NORMAL", "CNV", "DRUSEN"]
visualize_predictions(trained_model, test_dataloader, class_names, device)
